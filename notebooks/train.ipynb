# %% [markdown]
# # **Deep Generative Model for spectral image synthesis**
# * 2180034 - Brayan Esneider Monroy Chaparro
# * 2180045 - Geison Alfredo Blanco Rodriguez
# * 2180018 - Iván David Ortiz Pineda

# %% [markdown]
# ## Contextualización del problema
# Las **imágenes espectrales** contienen la información espacial y espectral de una escena. Esta información espectral resulta muy útil en áreas como, censado remoto, medicina y agricultura.
#
# <center><img src="https://www.spaceflightinsider.com/wp-content/uploads/2014/09/phoenix-img-2.jpg" width="50%"></center>
#
#
# **Justificación del problema:**
#
# Recientemente el Deep learning se ha incorporado entre las técnicas más prometedoras a la hora de resolver tareas de clasificación, segmentación, reconstrucción de imágenes espectrales. Sin embargo, como bien se sabe, la piedra angular del Deep learning son los datos, los cuales escasean y adicionalmente, la naturaleza de estas imágenes resulta ser de alta dimensionalidad lo cual aumenta la complejidad computacional a la hora de resolver las tareas mencionadas.
#
# Por consiguiente, para abordar ambas limitaciones en este trabajo se propone aprender una representación de baja dimensionalidad junto con un modelo generativo orientado a la síntesis de nuevas imágenes espectrales, permitiéndonos resolver los problemas sobre la representación de baja dimensionalidad y a su vez generar nuevos conjuntos de datos.

# %% [markdown]
# **Solución propuesta:**
#
# Un enfoque tradicional para la generación de imágenes haría uso de cierta arquitectura de red GAN (generative adversal network), en donde ingresando cierto target a la red generadora esta crearía la imagen espectral correspondiente y a través del discriminador se haría la validación sobre que tan real fue la imagen generada. Así durante el entrenamiento se buscaría aumentar la capacidad del generador para sintetizar imágenes reales.
#
# <center><img src="https://i.ibb.co/0VLnLzX/trad-1.png" width="60%"></center>

# %% [markdown]
# El **enfoque propuesto** en este trabajo consiste en el uso de una metodología en dos partes:
# * Primero, se plantea el uso de una arquitectura de red autoencoder para aprender una representación no lineal de las imágenes espectrales, a la vez que se empleará un discriminador para aprender a diferenciar las imágenes reales y falsas con el fin de mejorar la fiabilidad del autoencoder.
#
# <center><img src="https://i.ibb.co/tYYbPnM/architecture-1.png" width="80%"></center>
#
# * Segundo, se plantea la implementación de un algoritmo de optimización siguiendo una arquitectura de ADMM para, con los pesos previamente entrenados, poder realizar la síntesis de imágenes espectrales partiendo de imágenes a escala de grises. En esta etapa se busca específicamente el aprendizaje de la representación de baja dimensionalidad $\alpha$ que mejor describe la imagen espectral.
#
# <center><img src="https://i.ibb.co/TBDRc41/admm-1.png" width="60%"></center>

# %% [markdown]
# ## Entrenamiento de la red utilizada

# %%
#@title **Código:** Descarga repositorio e instalación de paquete
# !git clone https://github.com/bemc22/spectral-gans
# %cd spectral-gans
! pip install -r requirements.txt
# %cd ../
# Out:
# Cloning into 'spectral-gans'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 228 (delta 90), reused 189 (delta 56), pack-reused 0
# Receiving objects: 100% (228/228), 7.35 MiB | 2.77 MiB/s, done.
# Resolving deltas: 100% (90/90), done.
# /content/spectral-gans
# Obtaining file:///content/spectral-gans (from -r requirements.txt (line 1))
# Installing collected packages: spectral-gans
#   Running setup.py develop for spectral-gans
# Successfully installed spectral-gans-0.1
# /content

# %%
# ! rm -r spectral-gans

# %%
#@title **Código:** importando librerías

import tensorflow as tf
import numpy as np
from spectral_gans.models.main import make_encoder, make_generator, make_discriminator, spectralGAN
from spectral_gans.models.utils import discriminator_loss, autoencoder_loss, spec2rgb, get_RGB_matrix
from spectral_gans.models.metrics import PSNR, SSIM, SAM
from spectral_gans.data import load_dataset
import scipy.io as sio
import matplotlib.pyplot as plt

input_shape = (512,512,31)

# %%
#@title **Código:** cargando el dataset

BATCH_SIZE = 1

train_params = dict(
    batch_size = BATCH_SIZE,
    shuffle = True,
    cache = True
)

test_params = dict(
    batch_size = BATCH_SIZE,
    cache = True,
    shuffle = False
)

train_ds , test_ds = load_dataset( train_params = train_params, test_params = test_params)

# %%
start , stop, bands = 400, 720 , 31
RGB = get_RGB_matrix(start, stop, bands)

# %%
sample = next(iter(train_ds))
im = np.expand_dims(sample[0,...], axis = 0)

rgb = spec2rgb(im, RGB)
print( "minimo",np.min(rgb))
print( "maximo",np.max(rgb))

plt.figure(figsize=(10,10))
plt.imshow(np.power(rgb[0,:,:,:], 0.5))
print('\n\n',rgb[0, 0,0])
# Out:
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-6-c780fcb25baa> in <module>()
# ----> 1 sample = next(iter(train_ds))
#       2 im = np.expand_dims(sample[0,...], axis = 0)
#       3
#       4 rgb = spec2rgb(im, RGB)
#       5 print( "minimo",np.min(rgb))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     759   def __next__(self):
#     760     try:
# --> 761       return self._next_internal()
#     762     except errors.OutOfRangeError:
#     763       raise StopIteration
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     745           self._iterator_resource,
#     746           output_types=self._flat_output_types,
# --> 747           output_shapes=self._flat_output_shapes)
#     748
#     749       try:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    2726       return _result
#    2727     except _core._NotOkStatusException as e:
# -> 2728       _ops.raise_from_not_ok_status(e, name)
#    2729     except _core._FallbackException:
#    2730       pass
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# /usr/local/lib/python3.7/dist-packages/six.py in raise_from(value, from_value)
#
# UnknownError: FileNotFoundError: [Errno 2] No such file or directory: b'./data/kaist_dataset/train'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 645, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 892, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/content/spectral-gans/spectral_gans/data.py", line 24, in _generator
#     list_imgs = get_list_imgs(data_path)
#
#   File "/content/spectral-gans/spectral_gans/data.py", line 10, in get_list_imgs
#     list_imgs = os.listdir(data_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: b'./data/kaist_dataset/train'
#
#
# 	 [[{{node PyFunc}}]] [Op:IteratorGetNext]

# %%
#@title **Código:** definiendo el optimizador y arquitectura de la red

a_optimizer = tf.keras.optimizers.Adam(1e-3)
d_optimizer = tf.keras.optimizers.Adam(1e-6)

FACTOR = [ 1/8 , 1/8 , 1/4 , 1/2 , 1/2, 1]
features= 64

encoded_shape = input_shape[:-1] + (3,)

encoder = make_encoder(encoded_shape, features=features, factors=FACTOR)
generator = make_generator(input_shape, features=features, factors=FACTOR)
discriminator = make_discriminator(input_shape)

# %%
#@title **Código:** mostrando la arquitectura de las redes

encoder.summary()
generator.summary()
discriminator.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# encoder (Encoder)            (None, 512, 512, 64)      23120
# =================================================================
# Total params: 23,120
# Trainable params: 23,120
# Non-trainable params: 0
# _________________________________________________________________
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 512, 512, 64)]    0
# _________________________________________________________________
# generator (Generator)        (None, 512, 512, 31)      24398
# =================================================================
# Total params: 24,398
# Trainable params: 24,398
# Non-trainable params: 0
# _________________________________________________________________
# Model: "discriminator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 512, 512, 31 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# discriminator (Discriminator)   (None, 127, 127, 1)  42497       input_3[0][0]
#                                                                  input_4[0][0]
# ==================================================================================================
# Total params: 42,497
# Trainable params: 42,241
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %% [markdown]
# <center><img src="https://www.researchgate.net/profile/Gozde-Unal-2/publication/323904616/figure/fig1/AS:606457334595585@1521602104652/PatchGAN-discriminator-Each-value-of-the-output-matrix-represents-the-probability-of.png" width="55%"></center>

# %%
#@title **Código:** definiendo la arquitectura

from tensorflow.keras.callbacks import ModelCheckpoint

model = spectralGAN(encoder=encoder, generator=generator, discriminator=discriminator, CMF=RGB)

model.compile(
    a_optimizer = a_optimizer,
    d_optimizer = d_optimizer,
    a_loss = autoencoder_loss(tau=1e-3),
    d_loss = discriminator_loss,
    metrics = [ PSNR() , SSIM(), SAM ]
)


callbacks = [
             ModelCheckpoint( 'brayan_spectralGAN_rgb.h5', monitor='val_psnr',  verbose=1,  save_best_only=True,  save_weights_only=True,  mode="max", )
]

# %%
_input = np.zeros(input_shape)[None,:]

_ = model.__call__(_input)
# model.load_weights('spectralGAN.h5')

# %%
#@title **Código:** entrenando el modelo
history = model.fit(train_ds, epochs=300, validation_data=test_ds, callbacks=callbacks)
# Out:
# Epoch 1/300
# 9/9 [==============================] - 21s 1s/step - a_loss: 0.0109 - d_loss: 1.3916 - psnr: 19.8175 - ssim: 0.5543 - SAM: 49.6503 - real_acc: 0.2456 - fake_acc: 0.9391 - val_a_loss: 0.0102 - val_d_loss: 1.3868 - val_psnr: 19.7305 - val_ssim: 0.5822 - val_SAM: 47.8408 - val_real_acc: 0.4037 - val_fake_acc: 0.9426
#
# Epoch 00001: val_psnr improved from -inf to 19.73053, saving model to brayan_spectralGAN_rgb.h5
# Epoch 2/300
# 9/9 [==============================] - 8s 885ms/step - a_loss: 0.0078 - d_loss: 1.3899 - psnr: 20.9149 - ssim: 0.5931 - SAM: 42.7396 - real_acc: 0.2572 - fake_acc: 0.9397 - val_a_loss: 0.0083 - val_d_loss: 1.3866 - val_psnr: 20.5277 - val_ssim: 0.5910 - val_SAM: 44.0231 - val_real_acc: 0.3830 - val_fake_acc: 0.9845
#
# Epoch 00002: val_psnr improved from 19.73053 to 20.52772, saving model to brayan_spectralGAN_rgb.h5
# Epoch 3/300
# 9/9 [==============================] - 8s 881ms/step - a_loss: 0.0069 - d_loss: 1.3874 - psnr: 21.6812 - ssim: 0.6092 - SAM: 39.3400 - real_acc: 0.2454 - fake_acc: 0.9471 - val_a_loss: 0.0066 - val_d_loss: 1.3865 - val_psnr: 21.3162 - val_ssim: 0.6276 - val_SAM: 37.3018 - val_real_acc: 0.3791 - val_fake_acc: 0.9840
#
# Epoch 00003: val_psnr improved from 20.52772 to 21.31616, saving model to brayan_spectralGAN_rgb.h5
# Epoch 4/300
# 9/9 [==============================] - 8s 878ms/step - a_loss: 0.0051 - d_loss: 1.3871 - psnr: 22.4316 - ssim: 0.6678 - SAM: 31.9649 - real_acc: 0.2773 - fake_acc: 0.9620 - val_a_loss: 0.0052 - val_d_loss: 1.3866 - val_psnr: 22.1393 - val_ssim: 0.6540 - val_SAM: 34.6956 - val_real_acc: 0.3694 - val_fake_acc: 0.9566
#
# Epoch 00004: val_psnr improved from 21.31616 to 22.13928, saving model to brayan_spectralGAN_rgb.h5
# Epoch 5/300
# 9/9 [==============================] - 8s 879ms/step - a_loss: 0.0042 - d_loss: 1.3869 - psnr: 23.2570 - ssim: 0.6880 - SAM: 30.1002 - real_acc: 0.2933 - fake_acc: 0.9663 - val_a_loss: 0.0042 - val_d_loss: 1.3867 - val_psnr: 22.8595 - val_ssim: 0.6673 - val_SAM: 32.9013 - val_real_acc: 0.3514 - val_fake_acc: 0.9236
#
# Epoch 00005: val_psnr improved from 22.13928 to 22.85953, saving model to brayan_spectralGAN_rgb.h5
# Epoch 6/300
# 9/9 [==============================] - 8s 876ms/step - a_loss: 0.0035 - d_loss: 1.3867 - psnr: 23.8231 - ssim: 0.7084 - SAM: 29.2143 - real_acc: 0.2749 - fake_acc: 0.9712 - val_a_loss: 0.0037 - val_d_loss: 1.3869 - val_psnr: 23.2748 - val_ssim: 0.6869 - val_SAM: 32.0878 - val_real_acc: 0.3164 - val_fake_acc: 0.9255
#
# Epoch 00006: val_psnr improved from 22.85953 to 23.27480, saving model to brayan_spectralGAN_rgb.h5
# Epoch 7/300
# 9/9 [==============================] - 8s 887ms/step - a_loss: 0.0029 - d_loss: 1.3868 - psnr: 24.4183 - ssim: 0.7237 - SAM: 28.1049 - real_acc: 0.2789 - fake_acc: 0.9760 - val_a_loss: 0.0026 - val_d_loss: 1.3866 - val_psnr: 24.2704 - val_ssim: 0.7027 - val_SAM: 29.4751 - val_real_acc: 0.2927 - val_fake_acc: 0.9773
#
# Epoch 00007: val_psnr improved from 23.27480 to 24.27045, saving model to brayan_spectralGAN_rgb.h5
# Epoch 8/300
# 9/9 [==============================] - 8s 876ms/step - a_loss: 0.0020 - d_loss: 1.3867 - psnr: 25.2550 - ssim: 0.7359 - SAM: 26.7124 - real_acc: 0.2694 - fake_acc: 0.9790 - val_a_loss: 0.0020 - val_d_loss: 1.3863 - val_psnr: 24.9566 - val_ssim: 0.7068 - val_SAM: 28.8452 - val_real_acc: 0.2944 - val_fake_acc: 0.9889
#
# Epoch 00008: val_psnr improved from 24.27045 to 24.95663, saving model to brayan_spectralGAN_rgb.h5
# Epoch 9/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: 0.0019 - d_loss: 1.3880 - psnr: 25.6038 - ssim: 0.7374 - SAM: 26.5078 - real_acc: 0.2729 - fake_acc: 0.9787 - val_a_loss: 0.0018 - val_d_loss: 1.3864 - val_psnr: 25.3058 - val_ssim: 0.7320 - val_SAM: 28.5314 - val_real_acc: 0.2953 - val_fake_acc: 0.9812
#
# Epoch 00009: val_psnr improved from 24.95663 to 25.30576, saving model to brayan_spectralGAN_rgb.h5
# Epoch 10/300
# 9/9 [==============================] - 8s 873ms/step - a_loss: 0.0018 - d_loss: 1.3882 - psnr: 25.9292 - ssim: 0.7657 - SAM: 26.4753 - real_acc: 0.2718 - fake_acc: 0.9833 - val_a_loss: 0.0017 - val_d_loss: 1.3867 - val_psnr: 25.4534 - val_ssim: 0.7527 - val_SAM: 27.8087 - val_real_acc: 0.2847 - val_fake_acc: 0.9757
#
# Epoch 00010: val_psnr improved from 25.30576 to 25.45343, saving model to brayan_spectralGAN_rgb.h5
# Epoch 11/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: 0.0016 - d_loss: 1.3878 - psnr: 26.0379 - ssim: 0.7834 - SAM: 25.6921 - real_acc: 0.3022 - fake_acc: 0.9764 - val_a_loss: 0.0017 - val_d_loss: 1.3868 - val_psnr: 25.4290 - val_ssim: 0.7496 - val_SAM: 27.8863 - val_real_acc: 0.2679 - val_fake_acc: 0.9524
#
# Epoch 00011: val_psnr did not improve from 25.45343
# Epoch 12/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: 0.0016 - d_loss: 1.3877 - psnr: 26.0440 - ssim: 0.7868 - SAM: 25.8312 - real_acc: 0.2563 - fake_acc: 0.9784 - val_a_loss: 0.0016 - val_d_loss: 1.3868 - val_psnr: 25.5201 - val_ssim: 0.7702 - val_SAM: 26.0213 - val_real_acc: 0.2478 - val_fake_acc: 0.9734
#
# Epoch 00012: val_psnr improved from 25.45343 to 25.52011, saving model to brayan_spectralGAN_rgb.h5
# Epoch 13/300
# 9/9 [==============================] - 8s 873ms/step - a_loss: 0.0016 - d_loss: 1.3881 - psnr: 25.9322 - ssim: 0.7869 - SAM: 25.5072 - real_acc: 0.2675 - fake_acc: 0.9775 - val_a_loss: 0.0016 - val_d_loss: 1.3867 - val_psnr: 25.6134 - val_ssim: 0.7707 - val_SAM: 24.1828 - val_real_acc: 0.2340 - val_fake_acc: 0.9806
#
# Epoch 00013: val_psnr improved from 25.52011 to 25.61344, saving model to brayan_spectralGAN_rgb.h5
# Epoch 14/300
# 9/9 [==============================] - 8s 874ms/step - a_loss: 0.0013 - d_loss: 1.3872 - psnr: 26.3700 - ssim: 0.7689 - SAM: 25.2561 - real_acc: 0.2535 - fake_acc: 0.9759 - val_a_loss: 0.0014 - val_d_loss: 1.3866 - val_psnr: 25.7979 - val_ssim: 0.7396 - val_SAM: 27.4716 - val_real_acc: 0.2266 - val_fake_acc: 0.9762
#
# Epoch 00014: val_psnr improved from 25.61344 to 25.79794, saving model to brayan_spectralGAN_rgb.h5
# Epoch 15/300
# 9/9 [==============================] - 8s 879ms/step - a_loss: 0.0012 - d_loss: 1.3868 - psnr: 26.6173 - ssim: 0.7831 - SAM: 25.2938 - real_acc: 0.2750 - fake_acc: 0.9703 - val_a_loss: 0.0012 - val_d_loss: 1.3869 - val_psnr: 26.1653 - val_ssim: 0.7727 - val_SAM: 25.3339 - val_real_acc: 0.2175 - val_fake_acc: 0.9714
#
# Epoch 00015: val_psnr improved from 25.79794 to 26.16531, saving model to brayan_spectralGAN_rgb.h5
# Epoch 16/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: 0.0012 - d_loss: 1.3868 - psnr: 26.6782 - ssim: 0.7984 - SAM: 24.0303 - real_acc: 0.2691 - fake_acc: 0.9749 - val_a_loss: 0.0012 - val_d_loss: 1.3868 - val_psnr: 26.2059 - val_ssim: 0.7776 - val_SAM: 24.4096 - val_real_acc: 0.2101 - val_fake_acc: 0.9717
#
# Epoch 00016: val_psnr improved from 26.16531 to 26.20589, saving model to brayan_spectralGAN_rgb.h5
# Epoch 17/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: 0.0011 - d_loss: 1.3869 - psnr: 26.8308 - ssim: 0.8066 - SAM: 23.1866 - real_acc: 0.2487 - fake_acc: 0.9750 - val_a_loss: 0.0010 - val_d_loss: 1.3869 - val_psnr: 26.4254 - val_ssim: 0.7634 - val_SAM: 26.3429 - val_real_acc: 0.2018 - val_fake_acc: 0.9666
#
# Epoch 00017: val_psnr improved from 26.20589 to 26.42540, saving model to brayan_spectralGAN_rgb.h5
# Epoch 18/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: 9.6033e-04 - d_loss: 1.3864 - psnr: 26.9896 - ssim: 0.8150 - SAM: 22.7871 - real_acc: 0.2578 - fake_acc: 0.9757 - val_a_loss: 0.0011 - val_d_loss: 1.3868 - val_psnr: 26.4080 - val_ssim: 0.7950 - val_SAM: 22.6469 - val_real_acc: 0.1948 - val_fake_acc: 0.9674
#
# Epoch 00018: val_psnr did not improve from 26.42540
# Epoch 19/300
# 9/9 [==============================] - 8s 881ms/step - a_loss: 0.0011 - d_loss: 1.3866 - psnr: 27.2162 - ssim: 0.8241 - SAM: 21.6805 - real_acc: 0.2228 - fake_acc: 0.9726 - val_a_loss: 6.3031e-04 - val_d_loss: 1.3871 - val_psnr: 27.2392 - val_ssim: 0.7801 - val_SAM: 23.0387 - val_real_acc: 0.1888 - val_fake_acc: 0.9535
#
# Epoch 00019: val_psnr improved from 26.42540 to 27.23921, saving model to brayan_spectralGAN_rgb.h5
# Epoch 20/300
# 9/9 [==============================] - 8s 900ms/step - a_loss: 6.9221e-04 - d_loss: 1.3870 - psnr: 27.8551 - ssim: 0.8154 - SAM: 21.6006 - real_acc: 0.2480 - fake_acc: 0.9626 - val_a_loss: 3.8610e-04 - val_d_loss: 1.3871 - val_psnr: 27.7691 - val_ssim: 0.7853 - val_SAM: 21.9108 - val_real_acc: 0.1875 - val_fake_acc: 0.9498
#
# Epoch 00020: val_psnr improved from 27.23921 to 27.76910, saving model to brayan_spectralGAN_rgb.h5
# Epoch 21/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: 3.7258e-04 - d_loss: 1.3876 - psnr: 28.3234 - ssim: 0.8148 - SAM: 21.7622 - real_acc: 0.2395 - fake_acc: 0.9578 - val_a_loss: 1.2261e-04 - val_d_loss: 1.3870 - val_psnr: 28.4602 - val_ssim: 0.7798 - val_SAM: 23.3747 - val_real_acc: 0.1870 - val_fake_acc: 0.9528
#
# Epoch 00021: val_psnr improved from 27.76910 to 28.46024, saving model to brayan_spectralGAN_rgb.h5
# Epoch 22/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: 1.8798e-04 - d_loss: 1.3879 - psnr: 28.8110 - ssim: 0.8262 - SAM: 21.5596 - real_acc: 0.2444 - fake_acc: 0.9554 - val_a_loss: -3.6680e-05 - val_d_loss: 1.3871 - val_psnr: 28.9501 - val_ssim: 0.7849 - val_SAM: 22.2932 - val_real_acc: 0.1851 - val_fake_acc: 0.9488
#
# Epoch 00022: val_psnr improved from 28.46024 to 28.95009, saving model to brayan_spectralGAN_rgb.h5
# Epoch 23/300
# 9/9 [==============================] - 8s 894ms/step - a_loss: 1.2107e-04 - d_loss: 1.3880 - psnr: 29.0589 - ssim: 0.8396 - SAM: 19.9512 - real_acc: 0.2374 - fake_acc: 0.9413 - val_a_loss: -9.8959e-05 - val_d_loss: 1.3875 - val_psnr: 29.1617 - val_ssim: 0.8256 - val_SAM: 17.8241 - val_real_acc: 0.1800 - val_fake_acc: 0.9131
#
# Epoch 00023: val_psnr improved from 28.95009 to 29.16175, saving model to brayan_spectralGAN_rgb.h5
# Epoch 24/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: -7.7063e-05 - d_loss: 1.3881 - psnr: 29.5190 - ssim: 0.8544 - SAM: 18.9334 - real_acc: 0.2473 - fake_acc: 0.9141 - val_a_loss: -1.3346e-04 - val_d_loss: 1.3876 - val_psnr: 29.2837 - val_ssim: 0.8271 - val_SAM: 18.5399 - val_real_acc: 0.1733 - val_fake_acc: 0.8988
#
# Epoch 00024: val_psnr improved from 29.16175 to 29.28368, saving model to brayan_spectralGAN_rgb.h5
# Epoch 25/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: -8.8946e-05 - d_loss: 1.3881 - psnr: 29.5732 - ssim: 0.8546 - SAM: 18.4594 - real_acc: 0.2427 - fake_acc: 0.9069 - val_a_loss: -2.2255e-04 - val_d_loss: 1.3873 - val_psnr: 29.5761 - val_ssim: 0.7844 - val_SAM: 22.3113 - val_real_acc: 0.1668 - val_fake_acc: 0.9245
#
# Epoch 00025: val_psnr improved from 29.28368 to 29.57611, saving model to brayan_spectralGAN_rgb.h5
# Epoch 26/300
# 9/9 [==============================] - 8s 881ms/step - a_loss: -1.2237e-04 - d_loss: 1.3880 - psnr: 29.8471 - ssim: 0.8345 - SAM: 20.4826 - real_acc: 0.2258 - fake_acc: 0.8793 - val_a_loss: -3.0603e-04 - val_d_loss: 1.3879 - val_psnr: 29.9536 - val_ssim: 0.8313 - val_SAM: 17.0805 - val_real_acc: 0.1601 - val_fake_acc: 0.8800
#
# Epoch 00026: val_psnr improved from 29.57611 to 29.95356, saving model to brayan_spectralGAN_rgb.h5
# Epoch 27/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: -2.2140e-04 - d_loss: 1.3879 - psnr: 30.1463 - ssim: 0.8514 - SAM: 18.6201 - real_acc: 0.2175 - fake_acc: 0.8785 - val_a_loss: -2.3901e-04 - val_d_loss: 1.3884 - val_psnr: 29.7439 - val_ssim: 0.8441 - val_SAM: 16.4047 - val_real_acc: 0.1553 - val_fake_acc: 0.8936
#
# Epoch 00027: val_psnr did not improve from 29.95356
# Epoch 28/300
# 9/9 [==============================] - 8s 878ms/step - a_loss: -7.2352e-05 - d_loss: 1.3880 - psnr: 29.7387 - ssim: 0.8546 - SAM: 18.2646 - real_acc: 0.2120 - fake_acc: 0.8982 - val_a_loss: -3.3673e-04 - val_d_loss: 1.3876 - val_psnr: 30.0519 - val_ssim: 0.8290 - val_SAM: 18.5729 - val_real_acc: 0.1490 - val_fake_acc: 0.9085
#
# Epoch 00028: val_psnr improved from 29.95356 to 30.05193, saving model to brayan_spectralGAN_rgb.h5
# Epoch 29/300
# 9/9 [==============================] - 8s 869ms/step - a_loss: -1.1069e-04 - d_loss: 1.3877 - psnr: 29.6338 - ssim: 0.8651 - SAM: 17.5561 - real_acc: 0.2117 - fake_acc: 0.8807 - val_a_loss: -3.6234e-04 - val_d_loss: 1.3878 - val_psnr: 30.1276 - val_ssim: 0.7956 - val_SAM: 21.0995 - val_real_acc: 0.1430 - val_fake_acc: 0.9245
#
# Epoch 00029: val_psnr improved from 30.05193 to 30.12764, saving model to brayan_spectralGAN_rgb.h5
# Epoch 30/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: -6.3999e-05 - d_loss: 1.3878 - psnr: 29.5105 - ssim: 0.8403 - SAM: 18.9060 - real_acc: 0.2185 - fake_acc: 0.8945 - val_a_loss: 2.9943e-05 - val_d_loss: 1.3898 - val_psnr: 28.7812 - val_ssim: 0.7911 - val_SAM: 21.5065 - val_real_acc: 0.1375 - val_fake_acc: 0.8828
#
# Epoch 00030: val_psnr did not improve from 30.12764
# Epoch 31/300
# 9/9 [==============================] - 8s 876ms/step - a_loss: 1.2404e-04 - d_loss: 1.3877 - psnr: 29.2869 - ssim: 0.8520 - SAM: 19.2823 - real_acc: 0.2193 - fake_acc: 0.8628 - val_a_loss: -3.2323e-04 - val_d_loss: 1.3897 - val_psnr: 30.0349 - val_ssim: 0.8453 - val_SAM: 16.1390 - val_real_acc: 0.1298 - val_fake_acc: 0.8912
#
# Epoch 00031: val_psnr did not improve from 30.12764
# Epoch 32/300
# 9/9 [==============================] - 8s 877ms/step - a_loss: 5.9077e-07 - d_loss: 1.3879 - psnr: 29.6316 - ssim: 0.8584 - SAM: 18.0009 - real_acc: 0.2084 - fake_acc: 0.8919 - val_a_loss: -1.8262e-04 - val_d_loss: 1.3902 - val_psnr: 29.4964 - val_ssim: 0.8352 - val_SAM: 16.2645 - val_real_acc: 0.1270 - val_fake_acc: 0.8865
#
# Epoch 00032: val_psnr did not improve from 30.12764
# Epoch 33/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: -1.8877e-04 - d_loss: 1.3879 - psnr: 30.0140 - ssim: 0.8704 - SAM: 17.1871 - real_acc: 0.2105 - fake_acc: 0.8979 - val_a_loss: -4.3358e-04 - val_d_loss: 1.3894 - val_psnr: 30.4785 - val_ssim: 0.8345 - val_SAM: 18.0546 - val_real_acc: 0.1236 - val_fake_acc: 0.8972
#
# Epoch 00033: val_psnr improved from 30.12764 to 30.47852, saving model to brayan_spectralGAN_rgb.h5
# Epoch 34/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: -2.7239e-04 - d_loss: 1.3878 - psnr: 30.4639 - ssim: 0.8788 - SAM: 16.1972 - real_acc: 0.1977 - fake_acc: 0.9053 - val_a_loss: -3.6634e-04 - val_d_loss: 1.3898 - val_psnr: 30.1668 - val_ssim: 0.8253 - val_SAM: 18.5780 - val_real_acc: 0.1206 - val_fake_acc: 0.9107
#
# Epoch 00034: val_psnr did not improve from 30.47852
# Epoch 35/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -2.9469e-04 - d_loss: 1.3875 - psnr: 30.3398 - ssim: 0.8664 - SAM: 17.7345 - real_acc: 0.1991 - fake_acc: 0.9205 - val_a_loss: -3.6712e-04 - val_d_loss: 1.3903 - val_psnr: 30.1907 - val_ssim: 0.8493 - val_SAM: 15.4465 - val_real_acc: 0.1170 - val_fake_acc: 0.8981
#
# Epoch 00035: val_psnr did not improve from 30.47852
# Epoch 36/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -3.6296e-04 - d_loss: 1.3876 - psnr: 30.5065 - ssim: 0.8844 - SAM: 15.5987 - real_acc: 0.2031 - fake_acc: 0.9092 - val_a_loss: -3.9039e-04 - val_d_loss: 1.3899 - val_psnr: 30.3285 - val_ssim: 0.8311 - val_SAM: 18.2150 - val_real_acc: 0.1148 - val_fake_acc: 0.8988
#
# Epoch 00036: val_psnr did not improve from 30.47852
# Epoch 37/300
# 9/9 [==============================] - 8s 876ms/step - a_loss: -2.4177e-04 - d_loss: 1.3879 - psnr: 30.5093 - ssim: 0.8785 - SAM: 15.9289 - real_acc: 0.1886 - fake_acc: 0.9107 - val_a_loss: -4.9404e-04 - val_d_loss: 1.3901 - val_psnr: 30.7455 - val_ssim: 0.8535 - val_SAM: 16.0232 - val_real_acc: 0.1137 - val_fake_acc: 0.9163
#
# Epoch 00037: val_psnr improved from 30.47852 to 30.74549, saving model to brayan_spectralGAN_rgb.h5
# Epoch 38/300
# 9/9 [==============================] - 8s 870ms/step - a_loss: -1.9518e-04 - d_loss: 1.3875 - psnr: 30.4399 - ssim: 0.8715 - SAM: 16.7987 - real_acc: 0.1937 - fake_acc: 0.8896 - val_a_loss: -4.9688e-04 - val_d_loss: 1.3899 - val_psnr: 30.7477 - val_ssim: 0.8421 - val_SAM: 17.0530 - val_real_acc: 0.1115 - val_fake_acc: 0.9113
#
# Epoch 00038: val_psnr improved from 30.74549 to 30.74770, saving model to brayan_spectralGAN_rgb.h5
# Epoch 39/300
# 9/9 [==============================] - 8s 898ms/step - a_loss: -5.8119e-05 - d_loss: 1.3879 - psnr: 29.7790 - ssim: 0.8541 - SAM: 17.7772 - real_acc: 0.1953 - fake_acc: 0.8883 - val_a_loss: -2.9166e-04 - val_d_loss: 1.3892 - val_psnr: 29.9198 - val_ssim: 0.8138 - val_SAM: 19.5815 - val_real_acc: 0.1098 - val_fake_acc: 0.9302
#
# Epoch 00039: val_psnr did not improve from 30.74770
# Epoch 40/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: -3.6356e-04 - d_loss: 1.3875 - psnr: 30.3876 - ssim: 0.8786 - SAM: 16.6352 - real_acc: 0.1995 - fake_acc: 0.9056 - val_a_loss: -3.5500e-04 - val_d_loss: 1.3891 - val_psnr: 30.0843 - val_ssim: 0.8452 - val_SAM: 16.4347 - val_real_acc: 0.1088 - val_fake_acc: 0.9223
#
# Epoch 00040: val_psnr did not improve from 30.74770
# Epoch 41/300
# 9/9 [==============================] - 8s 874ms/step - a_loss:
300
# 9/9 [==============================] - 8s 874ms/step - a_loss: -5.6632e-04 - d_loss: 1.3863 - psnr: 31.7495 - ssim: 0.9060 - SAM: 13.5021 - real_acc: 0.1776 - fake_acc: 0.9072 - val_a_loss: -7.1250e-04 - val_d_loss: 1.3889 - val_psnr: 31.9456 - val_ssim: 0.8833 - val_SAM: 13.5243 - val_real_acc: 0.0954 - val_fake_acc: 0.9189
#
# Epoch 00067: val_psnr improved from 31.83171 to 31.94562, saving model to brayan_spectralGAN_rgb.h5
# Epoch 68/300
# 9/9 [==============================] - 8s 873ms/step - a_loss: -6.3230e-04 - d_loss: 1.3864 - psnr: 31.8801 - ssim: 0.9121 - SAM: 13.0240 - real_acc: 0.1896 - fake_acc: 0.9144 - val_a_loss: -7.2470e-04 - val_d_loss: 1.3900 - val_psnr: 32.0527 - val_ssim: 0.8816 - val_SAM: 13.2561 - val_real_acc: 0.0961 - val_fake_acc: 0.9155
#
# Epoch 00068: val_psnr improved from 31.94562 to 32.05275, saving model to brayan_spectralGAN_rgb.h5
# Epoch 69/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -6.1690e-04 - d_loss: 1.3865 - psnr: 31.8259 - ssim: 0.9072 - SAM: 13.2480 - real_acc: 0.1836 - fake_acc: 0.8985 - val_a_loss: -7.1459e-04 - val_d_loss: 1.3891 - val_psnr: 31.9704 - val_ssim: 0.8928 - val_SAM: 12.7170 - val_real_acc: 0.0966 - val_fake_acc: 0.9176
#
# Epoch 00069: val_psnr did not improve from 32.05275
# Epoch 70/300
# 9/9 [==============================] - 8s 884ms/step - a_loss: -5.7706e-04 - d_loss: 1.3865 - psnr: 31.5171 - ssim: 0.9099 - SAM: 12.8654 - real_acc: 0.1882 - fake_acc: 0.9012 - val_a_loss: -6.5846e-04 - val_d_loss: 1.3896 - val_psnr: 31.6318 - val_ssim: 0.8554 - val_SAM: 15.0204 - val_real_acc: 0.0969 - val_fake_acc: 0.9048
#
# Epoch 00070: val_psnr did not improve from 32.05275
# Epoch 71/300
# 9/9 [==============================] - 8s 878ms/step - a_loss: -5.3179e-04 - d_loss: 1.3864 - psnr: 31.3790 - ssim: 0.8939 - SAM: 14.2036 - real_acc: 0.1820 - fake_acc: 0.8969 - val_a_loss: -6.2339e-04 - val_d_loss: 1.3901 - val_psnr: 31.3690 - val_ssim: 0.8818 - val_SAM: 13.9964 - val_real_acc: 0.0974 - val_fake_acc: 0.9224
#
# Epoch 00071: val_psnr did not improve from 32.05275
# Epoch 72/300
# 9/9 [==============================] - 8s 876ms/step - a_loss: -5.0571e-04 - d_loss: 1.3861 - psnr: 31.3735 - ssim: 0.9016 - SAM: 13.9821 - real_acc: 0.1751 - fake_acc: 0.8981 - val_a_loss: -5.7784e-04 - val_d_loss: 1.3914 - val_psnr: 31.1789 - val_ssim: 0.8524 - val_SAM: 14.1552 - val_real_acc: 0.0973 - val_fake_acc: 0.8851
#
# Epoch 00072: val_psnr did not improve from 32.05275
# Epoch 73/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: -5.8040e-04 - d_loss: 1.3862 - psnr: 31.6150 - ssim: 0.9051 - SAM: 13.1216 - real_acc: 0.1787 - fake_acc: 0.9058 - val_a_loss: -6.9589e-04 - val_d_loss: 1.3897 - val_psnr: 31.8675 - val_ssim: 0.8910 - val_SAM: 12.6156 - val_real_acc: 0.0968 - val_fake_acc: 0.9132
#
# Epoch 00073: val_psnr did not improve from 32.05275
# Epoch 74/300
# 9/9 [==============================] - 8s 871ms/step - a_loss:
300
# 9/9 [==============================] - 8s 877ms/step - a_loss: -5.7656e-04 - d_loss: 1.3855 - psnr: 31.8892 - ssim: 0.9106 - SAM: 12.8433 - real_acc: 0.1960 - fake_acc: 0.8729 - val_a_loss: -5.3124e-04 - val_d_loss: 1.3889 - val_psnr: 30.9501 - val_ssim: 0.8394 - val_SAM: 15.4535 - val_real_acc: 0.1043 - val_fake_acc: 0.8962
#
# Epoch 00101: val_psnr did not improve from 32.33897
# Epoch 102/300
# 9/9 [==============================] - 8s 877ms/step - a_loss: -3.7595e-04 - d_loss: 1.3857 - psnr: 30.7736 - ssim: 0.8772 - SAM: 14.3574 - real_acc: 0.1968 - fake_acc: 0.8786 - val_a_loss: -7.1735e-04 - val_d_loss: 1.3871 - val_psnr: 31.9392 - val_ssim: 0.8634 - val_SAM: 14.3298 - val_real_acc: 0.1050 - val_fake_acc: 0.9074
#
# Epoch 00102: val_psnr did not improve from 32.33897
# Epoch 103/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: -4.2988e-04 - d_loss: 1.3853 - psnr: 31.1127 - ssim: 0.9096 - SAM: 12.4176 - real_acc: 0.1871 - fake_acc: 0.8841 - val_a_loss: -6.5329e-04 - val_d_loss: 1.3872 - val_psnr: 31.5767 - val_ssim: 0.8563 - val_SAM: 14.7620 - val_real_acc: 0.1049 - val_fake_acc: 0.9128
#
# Epoch 00103: val_psnr did not improve from 32.33897
# Epoch 104/300
# 9/9 [==============================] - 8s 877ms/step - a_loss: -6.3131e-04 - d_loss: 1.3854 - psnr: 31.8965 - ssim: 0.8979 - SAM: 13.0301 - real_acc: 0.1937 - fake_acc: 0.8791 - val_a_loss: -7.9515e-04 - val_d_loss: 1.3873 - val_psnr: 32.4439 - val_ssim: 0.8598 - val_SAM: 14.7545 - val_real_acc: 0.1057 - val_fake_acc: 0.9094
#
# Epoch 00104: val_psnr improved from 32.33897 to 32.44386, saving model to brayan_spectralGAN_rgb.h5
# Epoch 105/300
# 9/9 [==============================] - 8s 866ms/step - a_loss: -6.3864e-04 - d_loss: 1.3854 - psnr: 31.9666 - ssim: 0.9022 - SAM: 13.3734 - real_acc: 0.2027 - fake_acc: 0.8808 - val_a_loss: -7.9115e-04 - val_d_loss: 1.3871 - val_psnr: 32.4381 - val_ssim: 0.8240 - val_SAM: 16.8882 - val_real_acc: 0.1060 - val_fake_acc: 0.9037
#
# Epoch 00105: val_psnr did not improve from 32.44386
# Epoch 106/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -6.4311e-04 - d_loss: 1.3853 - psnr: 32.0372 - ssim: 0.8927 - SAM: 15.0998 - real_acc: 0.1983 - fake_acc: 0.8728 - val_a_loss: -7.5751e-04 - val_d_loss: 1.3879 - val_psnr: 32.2600 - val_ssim: 0.8843 - val_SAM: 13.3070 - val_real_acc: 0.1068 - val_fake_acc: 0.9098
#
# Epoch 00106: val_psnr did not improve from 32.44386
# Epoch 107/300
# 9/9 [==============================] - 8s 879ms/step - a_loss: -6.3778e-04 - d_loss: 1.3852 - psnr: 32.0789 - ssim: 0.9038 - SAM: 13.6636 - real_acc: 0.1881 - fake_acc: 0.8923 - val_a_loss: -7.9701e-04 - val_d_loss: 1.3882 - val_psnr: 32.5317 - val_ssim: 0.8908 - val_SAM: 12.6311 - val_real_acc: 0.1080 - val_fake_acc: 0.9040
#
# Epoch 00107: val_psnr improved from 32.44386 to 32.53173, saving model to brayan_spectralGAN_rgb.h5
# Epoch 108/300
# 9/9 [==============================] - 8s 871ms/step - a_loss: -7.0244e-04 - d_loss: 1.3853 - psnr: 32.3091 - ssim: 0.9039 - SAM: 13.6007 - real_acc: 0.1946 - fake_acc: 0.8904 - val_a_loss: -7.5321e-04 - val_d_loss: 1.3880 - val_psnr: 32.2189 - val_ssim: 0.8900 - val_SAM: 12.0028 - val_real_acc: 0.1081 - val_fake_acc: 0.9045
#
# Epoch 00108: val_psnr did not improve from 32.53173
# Epoch 109/300
# 9/9 [==============================] - 8s 871ms/step - a_loss: -6.4532e-04 - d_loss: 1.3852 - psnr: 32.3700 - ssim: 0.9119 - SAM: 13.0787 - real_acc: 0.2098 - fake_acc: 0.8712 - val_a_loss: -7.8094e-04 - val_d_loss: 1.3878 - val_psnr: 32.4760 - val_ssim: 0.8941 - val_SAM: 12.4476 - val_real_acc: 0.1089 - val_fake_acc: 0.9057
#
# Epoch 00109: val_psnr did not improve from 32.53173
# Epoch 110/300
# 9/9 [==============================] - 8s 869ms/step - a_loss: -6.8756e-04 - d_loss: 1.3854 - psnr: 32.4428 - ssim: 0.9077 - SAM: 13.1996 - real_acc: 0.1993 - fake_acc: 0.8749 - val_a_loss: -7.9258e-04 - val_d_loss: 1.3875 - val_psnr: 32.5153 - val_ssim: 0.8945 - val_SAM: 12.0475 - val_real_acc: 0.1094 - val_fake_acc: 0.9060
#
# Epoch 00110: val_psnr did not improve from 32.53173
# Epoch 111/300
# 9/9 [==============================] - 8s 865ms/step - a_loss: -7.1010e-04 - d_loss: 1.3853 - psnr: 32.5315 - ssim: 0.9145 - SAM: 12.6147 - real_acc: 0.1998 - fake_acc: 0.8856 - val_a_loss: -7.9189e-04 - val_d_loss: 1.3877 - val_psnr: 32.5234 - val_ssim: 0.8950 - val_SAM: 11.8680 - val_real_acc: 0.1099 - val_fake_acc: 0.9078
#
# Epoch 00111: val_psnr did not improve from 32.53173
# Epoch 112/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -6.4973e-04 - d_loss: 1.3852 - psnr: 32.4119 - ssim: 0.9120 - SAM: 12.4239 - real_acc: 0.1982 - fake_acc: 0.8896 - val_a_loss: -8.2895e-04 - val_d_loss: 1.3877 - val_psnr: 32.8040 - val_ssim: 0.8947 - val_SAM: 12.1932 - val_real_acc: 0.1105 - val_fake_acc: 0.9048
#
# Epoch 00112: val_psnr improved from 32.53173 to 32.80398, saving model to brayan_spectralGAN_rgb.h5
# Epoch 113/300
# 9/9 [==============================] - 8s 900ms/step - a_loss: -6.7441e-04 - d_loss: 1.3852 - psnr: 32.3066 - ssim: 0.9011 - SAM: 12.5788 - real_acc: 0.1948 - fake_acc: 0.8839 - val_a_loss: -7.5796e-04 - val_d_loss: 1.3881 - val_psnr: 32.2930 - val_ssim: 0.8951 - val_SAM: 11.7599 - val_real_acc: 0.1111 - val_fake_acc: 0.8996
#
# Epoch 00113: val_psnr did not improve from 32.80398
# Epoch 114/300
# 9/9 [==============================] - 8s 869ms/step - a_loss: -6.2832e-04 - d_loss: 1.3852 - psnr: 32.2600 - ssim: 0.9076 - SAM: 13.0162 - real_acc: 0.1989 - fake_acc: 0.8765 - val_a_loss: -7.9834e-04 - val_d_loss: 1.3874 - val_psnr: 32.5586 - val_ssim: 0.8727 - val_SAM: 13.7838 - val_real_acc: 0.1115 - val_fake_acc: 0.9020
#
# Epoch 00114: val_psnr did not improve from 32.80398
# Epoch 115/300
# 9/9 [==============================] - 8s 879ms/step - a_loss: -6.4139e-04 - d_loss: 1.3852 - psnr: 32.3372 - ssim: 0.9092 - SAM: 12.7956 - real_acc: 0.1974 - fake_acc: 0.8734 - val_a_loss: -7.9694e-04 - val_d_loss: 1.3868 - val_psnr: 32.5085 - val_ssim: 0.8684 - val_SAM: 13.9066 - val_real_acc: 0.1117 - val_fake_acc: 0.9037
#
# Epoch 00115: val_psnr did not improve from 32.80398
# Epoch 116/300
# 9/9 [==============================] - 8s 874ms/step - a_loss: -5.7432e-04 - d_loss: 1.3852 - psnr: 31.9394 - ssim: 0.9138 - SAM: 12.3114 - real_acc: 0.2005 - fake_acc: 0.8655 - val_a_loss: -7.9355e-04 - val_d_loss: 1.3876 - val_psnr: 32.5180 - val_ssim: 0.8917 - val_SAM: 11.9992 - val_real_acc: 0.1124 - val_fake_acc: 0.9031
#
# Epoch 00116: val_psnr did not improve from 32.80398
# Epoch 117/300
# 9/9 [==============================] - 8s 873ms/step - a_loss: -5.4942e-04 - d_loss: 1.3853 - psnr: 31.8857 - ssim: 0.9108 - SAM: 12.3478 - real_acc: 0.1946 - fake_acc: 0.8695 - val_a_loss: -7.1041e-04 - val_d_loss: 1.3872 - val_psnr: 31.9378 - val_ssim: 0.8476 - val_SAM: 15.2983 - val_real_acc: 0.1131 - val_fake_acc: 0.8966
#
# Epoch 00117: val_psnr did not improve from 32.80398
# Epoch 118/300
# ...
#
# Epoch 00260: val_psnr improved from 33.87355 to 34.02524, saving model to brayan_spectralGAN_rgb.h5
# Epoch 261/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -7.5528e-04 - d_loss: 1.3808 - psnr: 33.0647 - ssim: 0.9303 - SAM: 10.2423 - real_acc: 0.4091 - fake_acc: 0.7963 - val_a_loss: -7.8650e-04 - val_d_loss: 1.3791 - val_psnr: 32.7310 - val_ssim: 0.9078 - val_SAM: 10.9098 - val_real_acc: 0.5213 - val_fake_acc: 0.7535
#
# Epoch 00261: val_psnr did not improve from 34.02524
# Epoch 262/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -7.7684e-04 - d_loss: 1.3809 - psnr: 32.8763 - ssim: 0.9197 - SAM: 11.9277 - real_acc: 0.4394 - fake_acc: 0.7529 - val_a_loss: -6.2717e-04 - val_d_loss: 1.3803 - val_psnr: 31.6694 - val_ssim: 0.9011 - val_SAM: 11.4236 - val_real_acc: 0.5216 - val_fake_acc: 0.8527
#
# Epoch 00262: val_psnr did not improve from 34.02524
# Epoch 263/300
# 9/9 [==============================] - 8s 904ms/step - a_loss: -5.9168e-04 - d_loss: 1.3815 - psnr: 32.2269 - ssim: 0.9091 - SAM: 11.7493 - real_acc: 0.4407 - fake_acc: 0.7404 - val_a_loss: -8.2342e-04 - val_d_loss: 1.3798 - val_psnr: 32.7915 - val_ssim: 0.9054 - val_SAM: 11.6456 - val_real_acc: 0.5224 - val_fake_acc: 0.8453
#
# Epoch 00263: val_psnr did not improve from 34.02524
# Epoch 264/300
# 9/9 [==============================] - 8s 876ms/step - a_loss:
300
# 9/9 [==============================] - 8s 876ms/step - a_loss: -8.3075e-04 - d_loss: 1.3807 - psnr: 33.1992 - ssim: 0.9285 - SAM: 9.9793 - real_acc: 0.4271 - fake_acc: 0.7590 - val_a_loss: -8.1458e-04 - val_d_loss: 1.3792 - val_psnr: 32.8293 - val_ssim: 0.9113 - val_SAM: 10.0247 - val_real_acc: 0.5279 - val_fake_acc: 0.7888
#
# Epoch 00271: val_psnr did not improve from 34.02524
# Epoch 272/300
# 9/9 [==============================] - 8s 883ms/step - a_loss: -7.7357e-04 - d_loss: 1.3809 - psnr: 33.5001 - ssim: 0.9185 - SAM: 11.5211 - real_acc: 0.4670 - fake_acc: 0.7250 - val_a_loss: -8.9123e-04 - val_d_loss: 1.3794 - val_psnr: 33.4567 - val_ssim: 0.9205 - val_SAM: 9.8731 - val_real_acc: 0.5298 - val_fake_acc: 0.7931
#
# Epoch 00272: val_psnr did not improve from 34.02524
# Epoch 273/300
# 9/9 [==============================] - 8s 876ms/step - a_loss: -8.1745e-04 - d_loss: 1.3815 - psnr: 33.6880 - ssim: 0.9341 - SAM: 10.0902 - real_acc: 0.4790 - fake_acc: 0.7113 - val_a_loss: -9.2291e-04 - val_d_loss: 1.3811 - val_psnr: 33.5733 - val_ssim: 0.8828 - val_SAM: 12.4622 - val_real_acc: 0.5299 - val_fake_acc: 0.6581
#
# Epoch 00273: val_psnr did not improve from 34.02524
# Epoch 274/300
# 9/9 [==============================] - 8s 869ms/step - a_loss: -8.4979e-04 - d_loss: 1.3806 - psnr: 33.5628 - ssim: 0.9383 - SAM: 9.9731 - real_acc: 0.4727 - fake_acc: 0.7382 - val_a_loss: -9.0821e-04 - val_d_loss: 1.3791 - val_psnr: 33.4707 - val_ssim: 0.9196 - val_SAM: 10.2370 - val_real_acc: 0.5297 - val_fake_acc: 0.7538
#
# Epoch 00274: val_psnr did not improve from 34.02524
# Epoch 275/300
# 9/9 [==============================] - 8s 898ms/step - a_loss: -7.7457e-04 - d_loss: 1.3809 - psnr: 33.5028 - ssim: 0.9381 - SAM: 9.9897 - real_acc: 0.4609 - fake_acc: 0.7081 - val_a_loss: -9.4937e-04 - val_d_loss: 1.3804 - val_psnr: 33.9345 - val_ssim: 0.9038 - val_SAM: 11.2870 - val_real_acc: 0.5307 - val_fake_acc: 0.6851
#
# Epoch 00275: val_psnr did not improve from 34.02524
# Epoch 276/300
# 9/9 [==============================] - 8s 878ms/step - a_loss: -8.0112e-04 - d_loss: 1.3807 - psnr: 33.4578 - ssim: 0.9373 - SAM: 10.0221 - real_acc: 0.4607 - fake_acc: 0.7118 - val_a_loss: -9.1640e-04 - val_d_loss: 1.3799 - val_psnr: 33.5666 - val_ssim: 0.9201 - val_SAM: 10.2653 - val_real_acc: 0.5314 - val_fake_acc: 0.7103
#
# Epoch 00276: val_psnr did not improve from 34.02524
# Epoch 277/300
# 9/9 [==============================] - 8s 880ms/step - a_loss:
#
# Epoch 00283: val_psnr did not improve from 34.14565
# Epoch 284/300
# 9/9 [==============================] - 8s 883ms/step - a_loss: -8.6408e-04 - d_loss: 1.3804 - psnr: 33.5506 - ssim: 0.9283 - SAM: 10.5314 - real_acc: 0.4760 - fake_acc: 0.7440 - val_a_loss: -9.2071e-04 - val_d_loss: 1.3785 - val_psnr: 33.6164 - val_ssim: 0.9097 - val_SAM: 10.7900 - val_real_acc: 0.5378 - val_fake_acc: 0.7590
#
# Epoch 00284: val_psnr did not improve from 34.14565
# Epoch 285/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -8.6137e-04 - d_loss: 1.3806 - psnr: 33.3598 - ssim: 0.9126 - SAM: 11.2805 - real_acc: 0.4815 - fake_acc: 0.7410 - val_a_loss: -7.9275e-04 - val_d_loss: 1.3783 - val_psnr: 32.7044 - val_ssim: 0.9016 - val_SAM: 10.2192 - val_real_acc: 0.5387 - val_fake_acc: 0.7518
#
# Epoch 00285: val_psnr did not improve from 34.14565
# Epoch 286/300
# 9/9 [==============================] - 8s 903ms/step - a_loss: -8.5498e-04 - d_loss: 1.3811 - psnr: 33.6256 - ssim: 0.9311 - SAM: 10.1428 - real_acc: 0.4692 - fake_acc: 0.7457 - val_a_loss: -9.5802e-04 - val_d_loss: 1.3791 - val_psnr: 34.0383 - val_ssim: 0.9018 - val_SAM: 11.2300 - val_real_acc: 0.5402 - val_fake_acc: 0.8116
#
# Epoch 00286: val_psnr did not improve from 34.14565
# Epoch 287/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -8.2153e-04 - d_loss: 1.3808 - psnr: 33.4375 - ssim: 0.9393 - SAM: 9.6369 - real_acc: 0.4561 - fake_acc: 0.7416 - val_a_loss: -7.7815e-04 - val_d_loss: 1.3787 - val_psnr: 32.5137 - val_ssim: 0.9177 - val_SAM: 10.1216 - val_real_acc: 0.5413 - val_fake_acc: 0.7720
#
# Epoch 00287: val_psnr did not improve from 34.14565
# Epoch 288/300
# 9/9 [==============================] - 8s 884ms/step - a_loss: -8.1454e-04 - d_loss: 1.3820 - psnr: 33.3181 - ssim: 0.9263 - SAM: 11.0978 - real_acc: 0.4664 - fake_acc: 0.6940 - val_a_loss: -8.5372e-04 - val_d_loss: 1.3796 - val_psnr: 32.9525 - val_ssim: 0.8990 - val_SAM: 11.8077 - val_real_acc: 0.5426 - val_fake_acc: 0.7178
#
# Epoch 00288: val_psnr did not improve from 34.14565
# Epoch 289/300
# 9/9 [==============================] - 8s 905ms/step - a_loss: -8.3263e-04 - d_loss: 1.3802 - psnr: 33.2488 - ssim: 0.9351 - SAM: 9.9186 - real_acc: 0.5086 - fake_acc: 0.7486 - val_a_loss: -9.4401e-04 - val_d_loss: 1.3792 - val_psnr: 33.8868 - val_ssim: 0.9247 - val_SAM: 9.8169 - val_real_acc: 0.5444 - val_fake_acc: 0.7342
#
# Epoch 00289: val_psnr did not improve from 34.14565
# Epoch 290/300
# 9/9 [==============================] - 8s 878ms/step - a_loss: -6.9485e-04 - d_loss: 1.3807 - psnr: 32.7966 - ssim: 0.9207 - SAM: 10.4019 - real_acc: 0.4993 - fake_acc: 0.6912 - val_a_loss: -8.5657e-04 - val_d_loss: 1.3782 - val_psnr: 33.0060 - val_ssim: 0.9106 - val_SAM: 10.5230 - val_real_acc: 0.5449 - val_fake_acc: 0.7306
#
# Epoch 00290: val_psnr did not improve from 34.14565
# Epoch 291/300
# 9/9 [==============================] - 8s 878ms/step - a_loss: -8.0154e-04 - d_loss: 1.3803 - psnr: 33.6820 - ssim: 0.9418 - SAM: 9.4293 - real_acc: 0.5209 - fake_acc: 0.6929 - val_a_loss: -9.2898e-04 - val_d_loss: 1.3806 - val_psnr: 33.5917 - val_ssim: 0.8623 - val_SAM: 13.3910 - val_real_acc: 0.5448 - val_fake_acc: 0.5823
#
# Epoch 00291: val_psnr did not improve from 34.14565
# Epoch 292/300
# 9/9 [==============================] - 8s 879ms/step - a_loss: -7.6719e-04 - d_loss: 1.3809 - psnr: 33.5731 - ssim: 0.9182 - SAM: 10.3883 - real_acc: 0.4412 - fake_acc: 0.7201 - val_a_loss: -9.1676e-04 - val_d_loss: 1.3783 - val_psnr: 33.6510 - val_ssim: 0.9252 - val_SAM: 9.6792 - val_real_acc: 0.5454 - val_fake_acc: 0.8012
#
# Epoch 00292: val_psnr did not improve from 34.14565
# Epoch 293/300
# 9/9 [==============================] - 8s 872ms/step - a_loss: -8.6566e-04 - d_loss: 1.3798 - psnr: 33.5162 - ssim: 0.9332 - SAM: 10.1108 - real_acc: 0.4989 - fake_acc: 0.6988 - val_a_loss: -8.6481e-04 - val_d_loss: 1.3775 - val_psnr: 33.1994 - val_ssim: 0.9179 - val_SAM: 9.5924 - val_real_acc: 0.5457 - val_fake_acc: 0.7880
#
# Epoch 00293: val_psnr did not improve from 34.14565
# Epoch 294/300
# 9/9 [==============================] - 8s 884ms/step - a_loss: -8.6500e-04 - d_loss: 1.3804 - psnr: 33.6088 - ssim: 0.9424 - SAM: 9.3684 - real_acc: 0.4877 - fake_acc: 0.6886 - val_a_loss: -8.9010e-04 - val_d_loss: 1.3782 - val_psnr: 33.4409 - val_ssim: 0.9228 - val_SAM: 9.9143 - val_real_acc: 0.5466 - val_fake_acc: 0.7221
#
# Epoch 00294: val_psnr did not improve from 34.14565
# Epoch 295/300
# 9/9 [==============================] - 8s 878ms/step - a_loss: -8.5261e-04 - d_loss: 1.3812 - psnr: 33.5880 - ssim: 0.9317 - SAM: 10.2673 - real_acc: 0.4672 - fake_acc: 0.6788 - val_a_loss: -8.0073e-04 - val_d_loss: 1.3790 - val_psnr: 32.7067 - val_ssim: 0.9147 - val_SAM: 10.4195 - val_real_acc: 0.5475 - val_fake_acc: 0.6842
#
# Epoch 00295: val_psnr did not improve from 34.14565
# Epoch 296/300
# 9/9 [==============================] - 8s 897ms/step - a_loss: -8.4198e-04 - d_loss: 1.3808 - psnr: 33.5975 - ssim: 0.9434 - SAM: 9.0690 - real_acc: 0.4980 - fake_acc: 0.7297 - val_a_loss: -9.5018e-04 - val_d_loss: 1.3794 - val_psnr: 33.9357 - val_ssim: 0.9088 - val_SAM: 10.6753 - val_real_acc: 0.5475 - val_fake_acc: 0.6920
#
# Epoch 00296: val_psnr did not improve from 34.14565
# Epoch 297/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: -8.0149e-04 - d_loss: 1.3806 - psnr: 33.7012 - ssim: 0.9417 - SAM: 9.4483 - real_acc: 0.4790 - fake_acc: 0.7140 - val_a_loss: -9.6235e-04 - val_d_loss: 1.3794 - val_psnr: 34.0191 - val_ssim: 0.9065 - val_SAM: 10.8637 - val_real_acc: 0.5488 - val_fake_acc: 0.6892
#
# Epoch 00297: val_psnr did not improve from 34.14565
# Epoch 298/300
# 9/9 [==============================] - 8s 885ms/step - a_loss: -8.1241e-04 - d_loss: 1.3804 - psnr: 33.6762 - ssim: 0.9380 - SAM: 9.5908 - real_acc: 0.4874 - fake_acc: 0.7017 - val_a_loss: -9.0989e-04 - val_d_loss: 1.3793 - val_psnr: 33.5550 - val_ssim: 0.8979 - val_SAM: 11.5354 - val_real_acc: 0.5493 - val_fake_acc: 0.6517
#
# Epoch 00298: val_psnr did not improve from 34.14565
# Epoch 299/300
# 9/9 [==============================] - 8s 880ms/step - a_loss: -8.4972e-04 - d_loss: 1.3810 - psnr: 33.5059 - ssim: 0.9316 - SAM: 10.8841 - real_acc: 0.4642 - fake_acc: 0.7061 - val_a_loss: -9.0493e-04 - val_d_loss: 1.3769 - val_psnr: 33.5306 - val_ssim: 0.9232 - val_SAM: 9.8852 - val_real_acc: 0.5505 - val_fake_acc: 0.8285
#
# Epoch 00299: val_psnr did not improve from 34.14565
# Epoch 300/300
# 9/9 [==============================] - 8s 875ms/step - a_loss: -8.6405e-04 - d_loss: 1.3811 - psnr: 33.8295 - ssim: 0.9383 - SAM: 9.7782 - real_acc: 0.4622 - fake_acc: 0.6933 - val_a_loss: -9.5713e-04 - val_d_loss: 1.3792 - val_psnr: 33.8847 - val_ssim: 0.8962 - val_SAM: 11.3587 - val_real_acc: 0.5511 - val_fake_acc: 0.6896
#
# Epoch 00300: val_psnr did not improve from 34.14565

# %%
#@title **Código:** guardando los pesos
# model.save_weights('spectralGAN.h5')

# %%
#@title **Código:** mostrando la arquitectura general
model.summary()
# Out:
# Model: "spectral_gan"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Functional)         (None, 512, 512, 64)      23120
# _________________________________________________________________
# generator (Functional)       (None, 512, 512, 31)      24398
# _________________________________________________________________
# sequential (Sequential)      (None, 512, 512, 31)      47518
# _________________________________________________________________
# lambda (Lambda)              multiple                  0
# _________________________________________________________________
# discriminator (Functional)   (None, 127, 127, 1)       42497
# =================================================================
# Total params: 90,015
# Trainable params: 89,759
# Non-trainable params: 256
# _________________________________________________________________

# %%
#@title Training Results

fig, axs = plt.subplots(1, 4, figsize=(20,4))

axs[0].set_title("Autoencoder Loss")
axs[0].plot(history.history["a_loss"], label="train", c='k')
axs[0].plot(history.history["val_a_loss"], label="test", c='b')

axs[1].set_title("Discriminator Loss")
axs[1].plot(history.history["d_loss"], label="train", c='k')
axs[1].plot(history.history["val_d_loss"], label="test", c='b')


axs[2].set_title("Discriminator Real Accuracy")
axs[2].plot(history.history["real_acc"], label="train", c='k')
axs[2].plot(history.history["val_real_acc"], label="test", c='b')


axs[3].set_title("Discriminator Fake Accuracy")
axs[3].plot(history.history["fake_acc"], label="train", c='k')
axs[3].plot(history.history["val_fake_acc"], label="test", c='b')
axs[3].legend(loc='lower right')

plt.show()

# %%
#@title Metrics Results

fig, axs = plt.subplots(1, 3, figsize=(16,4))

axs[0].set_title("PSNR")
axs[0].plot(history.history["psnr"], label="train", c='k')
axs[0].plot(history.history["val_psnr"], label="test", c='b')

axs[1].set_title("SSIM")
axs[1].plot(history.history["ssim"], label="train", c='k')
axs[1].plot(history.history["val_ssim"], label="test", c='b')

axs[2].set_title("SAM")
axs[2].plot(history.history["SAM"], label="train", c='k')
axs[2].plot(history.history["val_SAM"], label="test", c='b')
axs[2].legend()

plt.show()

# %%
#@title Final Results
data = []

metrics = model.evaluate(train_ds, verbose=0)[:3]
metrics = [ round(a,3) for a in metrics]
data.append(["Train"] + metrics)
metrics = model.evaluate(test_ds, verbose=0)[:3]
metrics = [ round(a,3) for a in metrics]
data.append(["Test"] + metrics)

import pandas as pd

pd = pd.DataFrame(data=data, columns=["Dataset", "PSNR","SSIM", "SAM"])
pd = pd.set_index("Dataset")

pd.head()
# Out:
#            PSNR   SSIM     SAM
# Dataset
# Train    33.925  0.922  11.284
# Test     33.885  0.896  11.359

# %%
import cv2 

nums = 3

samples = next(iter(test_ds)).numpy()
_input = spec2rgb(samples, RGB)
generated = model.autoencoder.predict(_input)
generated_rgb = spec2rgb(generated, RGB)

# %%
#@title **Código:** mostrando imagenes generadas
fig, axs = plt.subplots(nums, 4, figsize=(15,12))

_ = [ ax.axis("off") for subax in axs for ax in subax]

axs[0,0].set_title("Input Image")
axs[0,1].set_title("Generated Image")
axs[0,2].set_title("Spectral Signature P1")
axs[0,3].set_title("Spectral Signature P2")

points = np.array([
          [200,250],
          [200,260],
          [190,190],
])

points2 = np.array([
          [300,250],
          [300,120],
          [390,240],
])

d = 8

for i in range(nums):

  point = points[i]
  point2 = points2[i]

  x_true = np.power( tf.clip_by_value(_input[i], 0 , 1), 0.5 )
  x_pred = np.power( tf.clip_by_value(generated_rgb[i], 0 , 1), 0.5 )

  x_pred = cv2.rectangle(x_pred, tuple(point - d), tuple(point + d), color=(0,255,255), thickness=3)
  x_pred = cv2.rectangle(x_pred, tuple(point2 - d), tuple(point2 + d), color=(255,0,255), thickness=3)

  axs[i,0].imshow(x_true)
  axs[i,1].imshow(x_pred)
  axs[i,2].axis("On")
  axs[i,3].axis("On")

  axs[i,2].plot( samples[i, point[1], point[0] ,:] , c='k', label="ground_truth")
  axs[i,2].plot( generated[i, point[1], point[0] ,:] , c='r', label="generated")


  axs[i,3].plot( samples[i, point2[1], point2[0] ,:] , c='k', label="ground_truth")
  axs[i,3].plot( generated[i, point2[1], point2[0] ,:] , c='r', label="generated")
  
axs[0,2].legend(loc="upper left")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
